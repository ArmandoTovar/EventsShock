-- %% [markdown]
-- # [dbo].[Detail]

-- %%
USE [STOCK]
GO

-- %%
/****** Object:  Table [dbo].[Detail]    Script Date: 11/8/2022 3:22:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detail](
	[id_Event] [uniqueidentifier] NOT NULL,
	[id_User] [uniqueidentifier] NOT NULL,
	[id] [uniqueidentifier] NOT NULL,
	[created_At] [datetime] NOT NULL,
 CONSTRAINT [PK_detail] PRIMARY KEY CLUSTERED 
(
	[id_Event] ASC,
	[id_User] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Events]

-- %%
/****** Object:  Table [dbo].[Events]    Script Date: 11/8/2022 3:22:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Events](
	[id] [uniqueidentifier] NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[created_At] [datetime] NOT NULL,
	[start_Date] [datetime] NOT NULL,
	[finish_Date] [datetime] NOT NULL,
	[image] [varchar](max) NULL,
 CONSTRAINT [PK_events] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 11/8/2022 3:22:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[id] [uniqueidentifier] NOT NULL,
	[created_At] [datetime] NOT NULL,
	[email] [nvarchar](50) NOT NULL,
	[password] [varchar](max) NOT NULL,
	[state] [bit] NOT NULL,
	[first_Name] [nvarchar](50) NULL,
	[last_Name] [nvarchar](50) NOT NULL,
	[birthdate] [datetime] NULL,
	[rol] [nchar](10) NOT NULL,
	[image] [varchar](max) NULL,
 CONSTRAINT [PK_user] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[work]

-- %%
/****** Object:  Table [dbo].[work]    Script Date: 11/8/2022 3:22:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[work](
	[name] [varchar](max) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_user_state]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_user_state]  DEFAULT ((1)) FOR [state]
GO

-- %% [markdown]
-- # [FK_detail_events]

-- %%
ALTER TABLE [dbo].[Detail]  WITH CHECK ADD  CONSTRAINT [FK_detail_events] FOREIGN KEY([id_Event])
REFERENCES [dbo].[Events] ([id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Detail] CHECK CONSTRAINT [FK_detail_events]
GO

-- %% [markdown]
-- # [FK_detail_users]

-- %%
ALTER TABLE [dbo].[Detail]  WITH CHECK ADD  CONSTRAINT [FK_detail_users] FOREIGN KEY([id_User])
REFERENCES [dbo].[Users] ([id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Detail] CHECK CONSTRAINT [FK_detail_users]
GO
